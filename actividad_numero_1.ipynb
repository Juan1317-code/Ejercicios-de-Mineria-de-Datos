# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan1317-code/Ejercicios-de-Mineria-de-Datos/blob/main/actividad_numero_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lista
# materias = ["Mineria de Datos", "Seguridad Informatica", "Formulacion de Proyectos", "Desarrollo para Moviles"]
# print("Materias del cuatrimestre:", materias)
#
# # Tupla
# coordenadas = (15, 30)
# print("Coordenadas:", coordenadas)
#
# # Diccionario
# empleado = {
#     "nombre": "JUAN",
#     "edad": 33,
#     "activo": True
# }
# print("Datos del empleado:", empleado)
#
# #print
# numero1 = 10
# numero2 = 5
# print("Suma:", numero1 + numero2)
# print("Multiplicación:", numero1 * numero2)
